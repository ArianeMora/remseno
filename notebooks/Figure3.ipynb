# %%
#
# The data from across switzerland: https://www.euforgen.org/member-countries/switzerland/
# Topological data of the forests as tiff files: https://www.swisstopo.admin.ch/de/geodata/images/ortho/swissimage10.html#technische_details

# %%
# Detail page for Unit number: CHE00053 and Target species: Sorbus torminalis

- Searching for species that cover 100%
http://portal.eufgis.org/search/simple/list/details-target/?tx_wfqbe_pi1[unit_number]=CHE00053&tx_wfqbe_pi1[target_species]=e0074764bc13b1207af3019abfc45058

# %%
from deepforest import main
from deepforest import get_data
import os
import matplotlib.pyplot as plt
model = main.deepforest()
model.use_release()
image_path = "/Users/ariane/Downloads/swissimage-dop10_2021_2657-1200_0.1_2056.tif"
img = model.predict_image(path=,return_plot=True)

#predict_image returns plot in BlueGreenRed (opencv style), but matplotlib likes RedGreenBlue, switch the channel order.
plt.imshow(img[:,:,::-1])
plt.savefig('output.tif')
# Out:
# Reading config file: /Users/ariane/opt/miniconda3/envs/rhm/lib/python3.10/site-packages/deepforest/data/deepforest_config.yml
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# No validation file provided. Turning off validation loop
# Model from DeepForest release https://github.com/weecology/DeepForest/releases/tag/1.0.0 was already downloaded. Loading model from file.
# Loading pre-built model: https://github.com/weecology/DeepForest/releases/tag/1.0.0
# /Users/ariane/opt/miniconda3/envs/rhm/lib/python3.10/site-packages/PIL/Image.py:3176: DecompressionBombWarning: Image size (100000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
image_path = "/Users/ariane/Downloads/swissimage-dop10_2021_2657-1200_0.1_2056.tif"

boxes = model.predict_image(path=image_path, return_plot = False)
# Out:
# /Users/ariane/opt/miniconda3/envs/rhm/lib/python3.10/site-packages/PIL/Image.py:3176: DecompressionBombWarning: Image size (100000000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
boxes
# Out:
#      xmin    ymin    xmax    ymax label     score
# 0   127.0     0.0  2175.0   975.0  Tree  0.193774  \
# 1  6770.0  6850.0  9725.0  9770.0  Tree  0.164111
# 2  8425.0  3414.0  9918.0  5187.0  Tree  0.147378
# 3    17.0  8125.0  1516.0  9928.0  Tree  0.138032
# 4   286.0  4703.0  1753.0  6144.0  Tree  0.132859
# 5  5833.0  4685.0  8417.0  7094.0  Tree  0.126245
# 6  1818.0  5335.0  3804.0  7416.0  Tree  0.123783
# 7  2444.0    23.0  4074.0  1149.0  Tree  0.112649
# 8     1.0  3108.0   849.0  4680.0  Tree  0.106712
# 9  7442.0    67.0  9978.0  2409.0  Tree  0.105059
#
#                                      image_path
# 0  swissimage-dop10_2021_2657-1200_0.1_2056.tif
# 1  swissimage-dop10_2021_2657-1200_0.1_2056.tif
# 2  swissimage-dop10_2021_2657-1200_0.1_2056.tif
# 3  swissimage-dop10_2021_2657-1200_0.1_2056.tif
# 4  swissimage-dop10_2021_2657-1200_0.1_2056.tif
# 5  swissimage-dop10_2021_2657-1200_0.1_2056.tif
# 6  swissimage-dop10_2021_2657-1200_0.1_2056.tif
# ...
